# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import pickle
import matplotlib.pyplot as plt
from sklearn.decomposition import KernelPCA
from sklearn.model_selection import GridSearchCV

# %%
def perform_kpca(indpen_X,dep_Y,n): 
    kpca = KernelPCA(n_components = n, kernel = 'rbf')
    X_train = kpca .fit_transform(indpen_X,dep_Y)
    return kpca, X_train

# %%
def split_scalar(indep_X,dep_Y):
        X_train, X_test, y_train, y_test = train_test_split(indep_X, dep_Y, test_size = 0.25, random_state = 0)
        sc = StandardScaler()
        X_train = sc.fit_transform(X_train)
        X_test = sc.transform(X_test)    
        return X_train, X_test, y_train, y_test

# %%
def cm_predition (classifier,X_test):
    y_pred = classifier.predict(X_test)
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, y_pred)
    from sklearn.metrics import accuracy_score
    accuracy= accuracy_score(y_test, y_pred)
    return cm,accuracy,classifier

# %%
def logistic(X_train, y_train,X_test):
    from sklearn.linear_model import LogisticRegression
    classifier = LogisticRegression(random_state = 0)
    classifier.fit(X_train, y_train)
    cm,accuracy,classifier = cm_predition(classifier,X_test)
    return cm,accuracy,classifier

# %%
def svm_linear(X_train,y_train,X_test):
    from sklearn.svm import SVC
    classifier = SVC(kernel = 'linear', random_state = 0)
    classifier.fit(X_train, y_train)
    cm,accuracy,classifier = cm_predition(classifier,X_test)
    return  cm,accuracy,classifier

# %%
def svm_NL(X_train,y_train,X_test):
    from sklearn.svm import SVC
    classifier = SVC(kernel = 'rbf', random_state = 0)
    classifier.fit(X_train, y_train)
    cm,accuracy,classifier = cm_predition(classifier,X_test)
    return  cm,accuracy,classifier

# %%
def Navie(X_train,y_train,X_test):
    from sklearn.naive_bayes import GaussianNB
    classifier = GaussianNB()
    classifier.fit(X_train, y_train)
    cm,accuracy,classifier = cm_predition(classifier,X_test)
    return  cm,accuracy,classifier

# %%
def knn(X_train,y_train,X_test):
    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    classifier.fit(X_train, y_train)
    cm,accuracy,classifier = cm_predition(classifier,X_test)
    return  cm,accuracy,classifier

# %%
def Decision(X_train,y_train,X_test):
    from sklearn.tree import DecisionTreeClassifier
    classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
    classifier.fit(X_train, y_train)
    cm,accuracy,classifier = cm_predition(classifier,X_test)
    return  cm,accuracy,classifier

# %%
def random(X_train,y_train,X_test):
    from sklearn.ensemble import RandomForestClassifier
    classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
    classifier.fit(X_train, y_train)
    cm,accuracy,classifier = cm_predition(classifier,X_test)
    return  cm,accuracy,classifier

# %%
def cm_predition (classifier,X_test):
    y_pred = classifier.predict(X_test)
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, y_pred)
    from sklearn.metrics import accuracy_score
    accuracy= accuracy_score(y_test, y_pred)
    return cm,accuracy,classifier

# %%
def kpca_classifier(acclog,accsvmlin,accsvmnl,accnav,accknn,accdec,accrand):
    
    dataframe=pd.DataFrame(index=['KPCA n=6'],columns=['Logistic','SVMlin','SVMNL','Navie','KNN','DT','RF'])
   
    for number,index in enumerate(dataframe.index):
        dataframe['Logistic'][index]=acclog[number]
        dataframe['SVMlin'][index]=accsvmlin[number]
        dataframe['SVMNL'][index]=accsvmnl[number]
        dataframe['Navie'][index]=accnav[number]
        dataframe['KNN'][index]=accknn[number]
        dataframe['DT'][index]=accdec[number]
        dataframe['RF'][index]=accrand[number]
    return dataframe

# %%
dataset1 = pd.read_csv("preprocessed-Flipkart Mobile.csv", index_col=None)
df2 = dataset1
df2 = pd.get_dummies(df2, drop_first=True)

indpen_X = df2.drop('sales_price', axis=1)
dep_Y = df2['sales_price']

# %%
df2
# Out:
#      ROM  RAM  display_size  num_rear_camera  battery_capacity  ratings  \
# 0     64    2           6.0                1              2500     4.50
# 1     64    4           6.0                2              2815     4.50
# 2     64    2           6.0                1              2500     4.50
# 3     64    3           6.1                1              2942     4.55
# 4    128    4           6.1                2              2815     4.55
# ..   ...  ...           ...              ...               ...      ...
# 425   32    3           6.0                2              4000     4.30
# 426   64    4           6.0                2              4000     4.30
# 427  128    6           6.5                3              4250     4.20
# 428   32    3           6.2                2              5000     4.20
# 429   32    3           6.0                2              4000     4.30
#
#      sales_price  discount_percent     sales  brand_Poco  ...  \
# 0          32999              0.17  71.83375       False  ...
# 1          54499              0.04   1.39000       False  ...
# 2          32999              0.17  71.83375       False  ...
# 3          42999              0.10  23.07000       False  ...
# 4          54499              0.02   5.15000       False  ...
# ..           ...               ...       ...         ...  ...
# 425         7999              0.30   1.50000       False  ...
# 426         9699              0.28   1.73000       False  ...
# 427        21999              0.12   3.42000       False  ...
# 428         8299              0.07   6.77000       False  ...
# 429         8190              0.31   1.53000       False  ...
#
#      processor_Exynos  processor_MediaTek  processor_Others  \
# 0               False               False             False
# 1               False               False             False
# 2               False               False             False
# 3               False               False             False
# 4               False               False             False
# ..                ...                 ...               ...
# 425             False               False             False
# 426             False               False             False
# 427             False               False             False
# 428             False               False             False
# 429             False               False             False
#
#      processor_Qualcomm  processor_Water  processor_iOS  screen_size_Medium  \
# 0                 False             True          False               False
# 1                 False            False          False               False
# 2                 False             True          False               False
# 3                 False            False           True                True
# 4                 False            False          False                True
# ..                  ...              ...            ...                 ...
# 425                True            False          False               False
# 426                True            False          False               False
# 427                True            False          False               False
# 428                True            False          False                True
# 429                True            False          False               False
#
#      screen_size_Small  screen_size_Very Large  screen_size_Very Small
# 0                False                   False                    True
# 1                 True                   False                   False
# 2                False                   False                    True
# 3                False                   False                   False
# 4                False                   False                   False
# ..                 ...                     ...                     ...
# 425               True                   False                   False
# 426               True                   False                   False
# 427              False                   False                   False
# 428              False                   False                   False
# 429               True                   False                   False
#
# [430 rows x 152 columns]

# %%
kpca,X_train_kpca= perform_kpca(indpen_X,dep_Y,8)
# created a empty list to append the final value
acclog=[]
accsvmlin=[]
accsvmnl=[]
accnav=[]
accknn=[]
accdec=[]
accrand=[]

# %%
X_train, X_test, y_train, y_test=split_scalar(X_train_kpca,dep_Y)

cm,accuracy,classifier=logistic(X_train,y_train,X_test)
acclog.append(accuracy)

cm,accuracy,classifier=svm_linear(X_train,y_train,X_test)
accsvmlin.append(accuracy)

cm,accuracy,classifier=svm_NL(X_train,y_train,X_test)
accsvmnl.append(accuracy)

cm,accuracy,classifier=Navie(X_train,y_train,X_test)
accnav.append(accuracy)

cm,accuracy,classifier=knn(X_train,y_train,X_test)
accknn.append(accuracy)

cm,accuracy,classifier=Decision(X_train,y_train,X_test)
accdec.append(accuracy)

cm,accuracy,classifier=random(X_train,y_train,X_test)
accrand.append(accuracy)
    
result =kpca_classifier(acclog,accsvmlin,accsvmnl,accnav,accknn,accdec,accrand)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11236\4293104907.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['Logistic'][index]=acclog[number]
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11236\4293104907.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['SVMlin'][index]=accsvmlin[number]
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11236\4293104907.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['SVMNL'][index]=accsvmnl[number]
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11236\4293104907.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['Navie'][index]=accnav[number]
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11236\4293104907.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['KNN'][index]=accknn[number]
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11236\4293104907.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['DT'][index]=accdec[number]
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11236\4293104907.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['RF'][index]=accrand[number]

# %%
result  
# 3
# Out:
#           Logistic    SVMlin     SVMNL     Navie       KNN   DT        RF
# KPCA n=6  0.157407  0.157407  0.157407  0.259259  0.259259  0.5  0.472222

# %%
result
# 4
# Out:
#           Logistic    SVMlin     SVMNL Navie   KNN        DT        RF
# KPCA n=6  0.166667  0.166667  0.166667  0.25  0.25  0.509259  0.481481

# %%
result
# 5
# Out:
#           Logistic    SVMlin     SVMNL     Navie   KNN        DT        RF
# KPCA n=6  0.166667  0.166667  0.166667  0.277778  0.25  0.472222  0.472222

# %%
result
# 6
# Out:
#           Logistic    SVMlin     SVMNL     Navie       KNN        DT        RF
# KPCA n=6  0.166667  0.166667  0.166667  0.296296  0.268519  0.509259  0.481481

# %%
result
# 8
# Out:
#           Logistic    SVMlin     SVMNL     Navie       KNN        DT        RF
# KPCA n=6  0.111111  0.148148  0.166667  0.296296  0.259259  0.537037  0.490741
