# %% [markdown]
# # Flipkart Mobile Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import chi2_contingency

# %%
dataset = pd.read_csv("preprocessed-Flipkart Mobile.csv")

# %%
dataset
# Out:
#       brand           model base_color processor screen_size  ROM  RAM  \
# 0     Apple       iPhone SE      Black     Water  Very Small   64    2
# 1     Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2     Apple       iPhone SE        Red     Water  Very Small   64    2
# 3     Apple       iPhone XR     Others       iOS      Medium   64    3
# 4     Apple       iPhone 12        Red   Ceramic      Medium  128    4
# ..      ...             ...        ...       ...         ...  ...  ...
# 425  Xiaomi     Redmi 6 Pro      Black  Qualcomm       Small   32    3
# 426  Xiaomi     Redmi 6 Pro        Red  Qualcomm       Small   64    4
# 427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  battery_capacity  ratings  sales_price  \
# ...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # 1. What is the distribution of tumor display_size ?

# %%
# Plot a histogram of tumor display_size
plt.hist(dataset['display_size'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Tumor display_size')
plt.xlabel('Tumor Radius')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 2.How are the texture values distributed across the dataset ?

# %%
plt.hist(dataset['display_size'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Tumor Texture')
plt.xlabel('Tumor Texture')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 3. What is the average perimeter of tumors in the dataset ?

# %%
average_perimeter = dataset['battery_capacity'].mean()
print("Average Perimeter of Tumors:", average_perimeter)
# Out:
# Average Perimeter of Tumors: 4530.560465116279

# %%
average_perimeter = dataset['battery_capacity'].median()
print("Average Perimeter of Tumors:", average_perimeter)
# Out:
# Average Perimeter of Tumors: 4500.0

# %%
average_perimeter = dataset['battery_capacity'].mode()
print("Average Perimeter of Tumors:", average_perimeter)
# Out:
# Average Perimeter of Tumors: 0    5000
# Name: battery_capacity, dtype: int64

# %% [markdown]
# # 4.What is the range of sales_price values observed in the dataset?

# %%
sales_price = dataset['sales_price'].max() - dataset['sales_price'].min()
print("Range of sales_price : ", sales_price)
# Out:
# Range of sales_price :  48757

# %% [markdown]
# # 5.What is the distribution of battery capacity  across the dataset ?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dataset['battery_capacity'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of battery_capacity')
plt.xlabel('battery_capacity')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # 6. What is the distribution of RAM ?

# %%
battery_age_years = dataset['RAM']

# Plotting the histogram
plt.figure(figsize=(8, 6))
plt.hist(battery_age_years, bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of RAM')
plt.xlabel('RAM')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # 7. What is the maintenance history distribution among the sales prices?

# %%
maintenance_history_counts = dataset['processor'].value_counts()

# Plotting the bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=maintenance_history_counts.index, y=maintenance_history_counts.values, palette='viridis')
plt.title('Distribution of processor')
plt.xlabel('processor')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3576\3131265732.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=maintenance_history_counts.index, y=maintenance_history_counts.values, palette='viridis')

# %% [markdown]
# # 8. How does the ratings vary across the dataset?

# %%
# Assuming 'Ratings' is the column name in your dataset
plt.figure(figsize=(8, 6))
sns.boxplot(x='ratings', data=dataset, palette='viridis')
plt.title('Distribution of ratings')
plt.xlabel('ratings')
plt.grid(True)
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3576\1263274953.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='ratings', data=dataset, palette='viridis')

# %% [markdown]
# # 9. What is the battery_capacity among the batteries?

# %%
# Assuming 'battery_capacity' is the column name in your dataset
capacity_range_min = dataset['battery_capacity'].min()
capacity_range_max = dataset['battery_capacity'].max()

print("Range of capacity among the batteries: {} to {}".format(capacity_range_min, capacity_range_max))
# Out:
# Range of capacity among the batteries: 2500 to 6500

# %% [markdown]
# # 10. What is the distribution of discount_percent ?

# %%
# Assuming 'discount_percent' is the column name in dataset
discount_percent = dataset['discount_percent']

plt.figure(figsize=(8, 6))
plt.hist(discount_percent, bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of discount_percent')
plt.xlabel('discount_percent')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # 11. How many display_size required ?

# %%
# Assuming 'display_size' is the column name in your dataset
display_size_count = dataset[dataset['display_size'] == 'Yes'].shape[0]

print("Number of batteries that require size:", display_size_count)
# Out:
# Number of batteries that require size: 0

# %% [markdown]
# # 12 . How many num_rear_camera need maintenance?

# %%
# Assuming 'sales_price' is the column name in dataset
maintenance_required_count = dataset[dataset['num_rear_camera'] == 'Yes'].shape[0]

print("num_rear_camera that need maintenance:", maintenance_required_count)
# Out:
# num_rear_camera that need maintenance: 0

# %% [markdown]
# # 13. What is the distribution of sales ?

# %%
# Assuming 'sales' is the column name in your dataset
sales_distribution = dataset['sales'].value_counts()

print("Distribution of Sales:")
print(sales_distribution)
# Out:
# Distribution of Sales:
# sales
# 71.83375    55
# 23.07000     9
# 25.76000     9
# 1.76000      6
# 5.15000      6
#             ..
# 59.54000     1
# 40.12000     1
# 23.21000     1
# 1.74000      1
# 1.53000      1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # 1.Is there a correlation between tumor discount and sales ?

# %%
correlation = dataset['discount_percent'].corr(dataset['sales'])
print("Correlation between Tumor discount and sales :", correlation)
# Out:
# Correlation between Tumor discount and sales : 0.24422173687669124

# %% [markdown]
# # 2.Is there a correlation between tumor battery and tumor sales?

# %%
correlation = dataset['battery_capacity'].corr(dataset['sales_price'])
print("Correlation between tumor battery_capacity and tumor sales_price :", correlation)
# Out:
# Correlation between tumor battery_capacity and tumor sales_price : -0.5976332578378559

# %% [markdown]
# # # 3.What is the relationship between display_size and discount_percent of tumors?

# %%
plt.scatter(dataset['display_size'], dataset['discount_percent'], color='skyblue')
plt.title('Relationship between display and discount')
plt.xlabel('Tumor display_size')
plt.ylabel('Tumor discount_percent')
plt.show()

# %% [markdown]
# #  4.What is the relationship between ROM and RAM of tumors?

# %%
plt.scatter(dataset['ROM'], dataset['RAM'], color='skyblue')
plt.title('Relationship between Tumor ROM and RAM')
plt.xlabel('Tumor ROM')
plt.ylabel('Tumor RAM')
plt.show()

# %% [markdown]
# # 5. Is there a correlation between sales_price and the sales ?

# %%
# Convert 'sales' column to numerical values
dataset['sales'] = dataset['sales'].map({'Yes': 1, 'No': 0})

# Now compute the correlation coefficient
correlation = dataset['sales_price'].corr(dataset['sales'])

print("Correlation Coefficient:", correlation)
# Out:
# Correlation Coefficient: nan

# %% [markdown]
# # 6. Does battery_capacity correlate with the sales_price ?

# %%
# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(dataset['battery_capacity'], dataset['sales_price'], alpha=0.5)
plt.title('battery_capacity vs sales_price')
plt.xlabel('battery_capacity')
plt.ylabel('sales_price')
plt.grid(True)
plt.show()

# %% [markdown]
# # 7. Is there an association between RAM and the need for ratings?

# %%
# Create a contingency table
contingency_table = pd.crosstab(dataset['RAM'], dataset['ratings'])

# Perform chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the chi-square statistic and p-value
print("Chi-square Statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-square Statistic: 142.76424296693386
# p-value: 1.2648153430338817e-16

# %%
sns.pairplot(dataset)

# %% [markdown]
# # Correlation Heatmap of Tumor Characteristics

# %%
dataset.columns
# Out:
# Index(['brand', 'model', 'base_color', 'processor', 'screen_size', 'ROM',
#        'RAM', 'display_size', 'num_rear_camera', 'battery_capacity', 'ratings',
#        'sales_price', 'discount_percent', 'sales'],
#       dtype='object')

# %%
# Select relevant columns for heatmap
relevant_columns = ['ROM',
       'RAM', 'display_size', 'num_rear_camera', 'battery_capacity', 'ratings',
       'sales_price', 'discount_percent', 'sales']

# Calculate correlation matrix
correlation_matrix = dataset[relevant_columns].corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Tumor Characteristics')
plt.show()

# %% [markdown]
# # Covariance Heatmap of Tumor Characteristics

# %%
# Select relevant columns for heatmap
relevant_columns = ['ROM',
       'RAM', 'display_size', 'num_rear_camera', 'battery_capacity', 'ratings',
       'sales_price', 'discount_percent', 'sales']

# Calculate covariance matrix
covariance_matrix = dataset[relevant_columns].cov()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(covariance_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Covariance Heatmap of Tumor Characteristics')
plt.show()
